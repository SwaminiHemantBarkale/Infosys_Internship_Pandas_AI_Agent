# %% [markdown]
# <a href="https://colab.research.google.com/github/SwaminiHemantBarkale/Infosys_Internship_Pandas_AI_Agent/blob/main/Pandas_AI_Agent_Infosys_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas AI Agent - Rainfall in the USA**

# %%
# !pip install groq
# !pip install langchain-groq
# !pip install python-dotenv
# !pip install langchain-experimental

# %%
with open('.env', 'w') as f:
  f.write('GROQ_API_KEY=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')

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
from groq import Groq
from langchain_groq import ChatGroq
from langchain_experimental.agents.agent_toolkits import create_pandas_dataframe_agent
import pandas as pd

# %%
client = Groq(api_key=os.getenv("GROQ_API_KEY"))

# %%
llm = ChatGroq(model_name="llama3-70b-8192")

# %%
llm.invoke("Which state has the highest rainfall in India?")
# Out:
# AIMessage(content='The state with the highest rainfall in India is Cherrapunji, which is located in the state of Meghalaya in the Northeastern part of the country. Cherrapunji holds the record for the highest average annual rainfall in India, with an average of over 11,777 mm (463.6 inches) of rainfall every year.\n\nIn fact, Cherrapunji is often referred to as the "Wettest Place on Earth" due to its extremely high rainfall. The region\'s unique geography, with its proximity to the Bay of Bengal and the Khasi Hills, contributes to its high rainfall. The monsoon season in Cherrapunji is particularly intense, with most of the rainfall occurring between June and September.\n\nOther states in India that receive high rainfall include:\n\n* Kerala: Known for its tropical monsoon climate, Kerala receives an average of around 3,000 mm (118 inches) of rainfall every year.\n* Assam: Located in the Northeastern part of India, Assam receives an average of around 2,500 mm (98 inches) of rainfall 
# ...

# %%
df= pd.read_csv('/content/usa_rain_prediction_dataset_2024_2025.csv')

# %%
df.shape
# Out:
# (73100, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73100 entries, 0 to 73099
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           73100 non-null  object
#  1   Location       73100 non-null  object
#  2   Temperature    73100 non-null  float64
#  3   Humidity       73100 non-null  float64
#  4   Wind Speed     73100 non-null  float64
#  5   Precipitation  73100 non-null  float64
#  6   Cloud Cover    73100 non-null  float64
#  7   Pressure       73100 non-null  float64
#  8   Rain Tomorrow  73100 non-null  int64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 5.0+ MB

# %%
df.head(5)
# Out:
#          Date  Location  Temperature   Humidity  Wind Speed  Precipitation  \
# 0  2024-01-01  New York    87.524795  75.655455   28.379506       0.000000
# 1  2024-01-02  New York    83.259325  28.712617   12.436433       0.526995
# 2  2024-01-03  New York    80.943050  64.740043   14.184831       0.916884
# 3  2024-01-04  New York    78.097552  59.738984   19.444029       0.094134
# 4  2024-01-05  New York    37.059963  34.766784    3.689661       1.361272
#
#    Cloud Cover     Pressure  Rain Tomorrow
# 0    69.617966  1026.030278              0
# 1    41.606048   995.962065              0
# 2    77.364763   980.796739              1
# 3    52.541196   979.012163              0
# 4    85.584000  1031.790859              0

# %%
df.tail(5)
# Out:
#              Date         Location  Temperature   Humidity  Wind Speed  \
# 73095  2025-12-27  Washington D.C.    40.614393  65.099438   28.778327
# 73096  2025-12-28  Washington D.C.    52.641643  30.610525   12.282890
# 73097  2025-12-29  Washington D.C.    56.492591  96.740232    2.894762
# 73098  2025-12-30  Washington D.C.    65.748956  63.900004   24.632400
# 73099  2025-12-31  Washington D.C.    54.648609  80.812021   22.722505
#
#        Precipitation  Cloud Cover     Pressure  Rain Tomorrow
# 73095       0.000000    54.168514   977.083747              0
# 73096       0.871000    22.068055   980.591675              0
# 73097       1.191956    52.336048  1016.469174              1
# 73098       0.483421    76.785280  1032.396146              1
# 73099       0.151903    19.674960   974.835534              0

# %%
df.describe()
# Out:
#         Temperature      Humidity    Wind Speed  Precipitation   Cloud Cover  \
# count  73100.000000  73100.000000  73100.000000   73100.000000  73100.000000
# mean      65.182270     59.875041     15.017946       0.390635     54.942807
# std       20.205793     23.066115      8.668729       0.474833     25.982487
# min       30.000766     20.000272      0.000712       0.000000     10.000856
# 25%       47.678968     39.800732      7.485182       0.000000     32.318668
# 50%       65.294949     59.887840     15.102495       0.196909     55.011121
# 75%       82.636570     79.835990     22.551794       0.673177     77.412469
# max       99.997393     99.999025     29.999017       3.078090     99.998957
#
#            Pressure  Rain Tomorrow
# count  73100.000000   73100.000000
# mean    1005.176013       0.220410
# std       20.203889       0.414526
# min      970.000919       0.000000
# 25%      987.697646       0.000000
# 50%     1005.284188       0.000000
# ...

# %%
agent = create_pandas_dataframe_agent(llm,df,verbose=True, allow_dangerous_code=True)

# %%
result= llm.invoke("What is the highest value of temperature and humidity in the given dataframe? ")

# %%
print("Your Answer is",result)
# Out:
# Your Answer is content='Assuming you have a Pandas dataframe named `df` with columns \'temperature\' and \'humidity\', you can find the highest value of temperature and humidity using the `max()` function:\n\n```\nmax_temp = df[\'temperature\'].max()\nmax_humidity = df[\'humidity\'].max()\n\nprint(f"Maximum temperature: {max_temp}")\nprint(f"Maximum humidity: {max_humidity}")\n```\n\nThis will output the highest value of temperature and humidity in the dataframe.\n\nIf you want to find the row with the highest value of temperature and humidity, you can use the `idxmax()` function:\n\n```\nmax_temp_index = df[\'temperature\'].idxmax()\nmax_humidity_index = df[\'humidity\'].idxmax()\n\nprint(f"Row with maximum temperature: {df.loc[max_temp_index]}")\nprint(f"Row with maximum humidity: {df.loc[max_humidity_index]}")\n```\n\nThis will output the entire row with the highest value of temperature and humidity.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 198
# ...
